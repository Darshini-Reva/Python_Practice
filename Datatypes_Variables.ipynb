# %% [markdown]
# ## Variables

# %%
name = "Lucky"
institue = "Edukron"
age = 23
height = 5.5
is_student = False
gender = "Male"

# %%
type(name)
# Out:
# str

# %%
type(age)
# Out:
# int

# %%
type(height)
# Out:
# float

# %%
type(is_student)
# Out:
# bool

# %%
type(institue)
# Out:
# str

# %%
## Varaibles

# %%
name
# Out:
# 'Lucky'

# %%
age
# Out:
# 23

# %%
height
# Out:
# 5.5

# %%
is_student
# Out:
# False

# %%
gender
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 gender
#
# NameError: name 'gender' is not defined

# %%
gender
# Out:
# 'Male'

# %%
1name = "Lucky"     # variable should start with Letters or underscore
institue = "Edukron"
age = 23
height = 5.5
is_student = False
gender = "Male"
# Out:
#   Cell In[22], line 1
#     1name = "Lucky"     # variable should start with Letters or underscore
#     ^
# SyntaxError: invalid decimal literal

# %%
name1 = "Lucky"     # variable can end with numbers
institue = "Edukron"
age = 23
height = 5.5
is_student = False
gender = "Male"

# %%
# no space or special charaters

first_name = "Sony"
first@name = "Sony"
first name = "Sony"
# Out:
#   Cell In[24], line 4
#     first@name = "Sony"
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
# case sensitive
name = "Amit"
Name = "Sumit"
naMe = "Namit"

# %%
name
# Out:
# 'Amit'

# %%
Name
# Out:
# 'Sumit'

# %%
naMe
# Out:
# 'Namit'

# %%
# cannot use as Python keywords (if, foe, while, class, def, return)

if = 4
# Out:
#   Cell In[31], line 3
#     if = 4
#        ^
# SyntaxError: invalid syntax

# %%
# Mistakes to avoid

2student = 25
first-name = "Sam"
class = "Python"
# Out:
#   Cell In[35], line 3
#     2student = 25
#     ^
# SyntaxError: invalid decimal literal

# %%
student2 = 25
first_name = "Sam"
class_name = "Python"

# %%
name = "Lucky"
institue = "Edukron"
age = 23
height = 5.5
is_student = False
gender = "Male"

# %%
print(name)
print(gender)
# Out:
# Lucky
# Male

# %% [markdown]
# #### Python Operators

# %%
# Arithematic operators

10+5
# Out:
# 15

# %%
10-5
# Out:
# 5

# %%
10*5
# Out:
# 50

# %%
10/4
# Out:
# 2.5

# %%
10//4
# Out:
# 2

# %%
10%4
# Out:
# 2

# %%
2**4
# Out:
# 16

# %%
# Comparison Opertors

10 == 10
# Out:
# True

# %%
10 != 2
# Out:
# True

# %%
5 == 3
5 == 5
5 != 5
# Out:
# False

# %%
print (5 == 3)
print(5 == 5)
print(5 != 5)
# Out:
# False
# True
# False

# %%
x = 10
y = 20

# %%
print ( x == y)
print ( x != y)
print ( x > y)
print ( x < y)
print ( x >= y)
print ( x <= y)
# Out:
# False
# True
# False
# True
# False
# True

# %%
## Logical Operators

( 5 > 3 and 10 > 5)
# Out:
# True

# %%
( 5 > 3 and 10 < 5)
# Out:
# False

# %%
( 5 > 3 or 10 < 5)
# Out:
# True

# %%
( 5 < 3 or 10 < 5)
# Out:
# False

# %%
not( 5 > 3)
# Out:
# False

# %%
not( 5 < 3)
# Out:
# True

# %%
# Assignment Operators

x = 10

# %%
x
# Out:
# 10

# %%
x += 5  # x = x + 5 (x = 10 + 5)

# %%
x
# Out:
# 15

# %%
x -= 4 # x = x - 4 (x = 15 - 4)

# %%
x
# Out:
# 11

# %%
x *= 2

# %%
x
# Out:
# 22

# %%
x /= 2

# %%
x
# Out:
# 11.0

# %%
x //= 2

# %%
x
# Out:
# 5.0

# %%
x = 10000
print(x)
# Out:
# 10000

# %%
x %= 2

# %%
x
# Out:
# 0

# %%
x = 100
print(x)
# Out:
# 100

# %%
x **= 2

# %%
x
# Out:
# 10000

# %%
# Membership Operators

"a" in "apple"
# Out:
# True

# %%
"z" in "apple"
# Out:
# False

# %%
"Data" not in "Data Engineering"
# Out:
# False

# %%
"Science" not in "Data Engineering"
# Out:
# True

# %%
x = [1, 2, 3]
z = [1, 2, 3]

# %%
print (x is z)
print (x is not z)
# Out:
# False
# True

# %%
# Identity Operators

x = [1, 2, 3]
y = x
z = [1, 2, 3]

# %%
print (x is z)
print (x is y)
print (x is not z)
# Out:
# False
# True
# True

# %% [markdown]
# ### print() function

# %%
print ("Hello World from Python")
print (5)
print (10+24)
# Out:
# Hello World from Python
# 5
# 34

# %%
name = "Lucky"
age = 23

print ("My name is" name "My age is" age)
# Out:
#   Cell In[7], line 4
#     print ("My name is" name "My age is" age)
#            ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
name = "Lucky"
age = 23

print ("My name is", name,"My age is", age)
# Out:
# My name is Lucky My age is 23

# %%
name = "Lucky"
age = 23

print ("My name is", name,"," "My age is", age)
# Out:
# My name is Lucky ,My age is 23
