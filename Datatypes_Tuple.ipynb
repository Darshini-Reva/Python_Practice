# %% [markdown]
# ## Tuple

# %%
empty_tuple = ()

# %%
print(empty_tuple)
# Out:
# ()

# %%
empty_tuple.append(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 empty_tuple.append(10)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
tech_skills = ("Python", "SQL", "Git", "CI/CD", "Python")
course_info = ("DS101", "Data Science", 15, 4.8)

# %%
tech_skills[2]
# Out:
# 'Git'

# %%
tech_skills[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 tech_skills[5]
#
# IndexError: tuple index out of range

# %%
tech_skills[-1]
# Out:
# 'Python'

# %%
tech_skills[:2]
# Out:
# ('Python', 'SQL')

# %%
tech_skills[-2:]
# Out:
# ('CI/CD', 'Python')

# %% [markdown]
# #### tuple.count()

# %%
tech_skills = ("Python", "SQL", "Git", "CI/CD", "Python", "SQL", "Python")
ratings = (5, 4, 5, 5, 3, 4, 5)

# %%
python_count = tech_skills.count("Python")
print(python_count)
# Out:
# 3

# %%
sql_count = tech_skills.count("SQL")
print(sql_count)
# Out:
# 2

# %%
tuple_created = (1,2,3,4,5)

# %%
type(tuple_created)
# Out:
# tuple

# %%
converted_to_list = list(tuple_created)
print(converted_to_list)
# Out:
# [1, 2, 3, 4, 5]

# %%
type(converted_to_list)
# Out:
# list

# %%
converted_to_list.append(6)
print(converted_to_list)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
converted_to_tuple = tuple(converted_to_list)
print(converted_to_tuple)
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
converted_to_tuple.append(7)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 converted_to_tuple.append(7)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
a = "123"

# %%
type(a)
# Out:
# str

# %%
type(int(a))
# Out:
# int

# %%
list(tuple)

# %%
tuple(list)
