# %%
name="Darshini"
age=28
Learner="Data Engineering"
Training=True

# %%
type(name)
# Out:
# str

# %%
type(age)
# Out:
# int

# %%
type(Learner)
# Out:
# str

# %%
type(Training)
# Out:
# bool

# %%
Student='Kiran'

# %%
type(student)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 type(student)
#
# NameError: name 'student' is not defined

# %%
type(Student)
# Out:
# str

# %%
height=1.2

# %%
type(height)
# Out:
# float
